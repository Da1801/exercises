# %% [markdown]
# The file "studentInfo.csv" contains information about the registration and deregistration date of students. If a student has not yet been deregistered, the value of the deregistration date is None. The dates are in the following format dd/mm/yyyy.

# %% [markdown]
# Read the file in a panda dataframe.

# %% [markdown]
# Show the first rows to see if this was successful.

# %% [markdown]
# Delete all rows with a non-valid date in the column "unsubscribe date" (None is of course also a non-valid date).
# Show the first rows again to see if this was successful

# %% [markdown]
# Delete all rows with an invalid date in the "registration date" column.

# %% [markdown]
# Create a new column "number of days" that contains the number of days between enrolment and deregistration date.

# %% [markdown]
# Delete all rows for which the "number of days" column has a negative value.

# %% [markdown]
#  Provide a visual overview in the form of a histogram of the number of students enrolled for the same number of days.
#  Example:
#
# ![output.png contains an image of the expected output. A histogram is shown with "aantal dagen ingeschreven" on the x-axis and "aantal studenten" on the y-axis.](output.png)
